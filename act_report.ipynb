# %% [markdown]
# ## Report: act_report

# %% [markdown]
# This report communicate the insights and displays the visualizations produced from the wrangled data of the WeRateDog.
#
# ![Screenshot%20%28164%29.png](attachment:Screenshot%20%28164%29.png)
#
# WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog. These ratings almost always have a denominator of 10. The numerators, though? Almost always greater than 10. 11/10, 12/10, 13/10, etc. Why? Because "they're good dogs Brent."
#
# ![Screenshot%20%28167%29.png](attachment:Screenshot%20%28167%29.png)
#
# WeRateDogs has over 4 million followers and has received international media coverage.
#
# ### Insights and Visualization
#
# #### Relationship betweet dog types and retweet counts
#
# A sum plot was plotted to show the replationship between the dog types and the retweet counts![Screenshot%20%28160%29.png](attachment:Screenshot%20%28160%29.png)
#
# 1. pupper has the highest retweet counts with 512173 retweets in total
#
# 2. floofer has the lowest retweet counts with 25587 retweets in total
#
#
# #### Relationship between dog types and favorite counts
#
# A bar chart was plotted to show the  mean relationship between dog types and favorite counts.![Screenshot%20%28159%29.png](attachment:Screenshot%20%28159%29.png)
#
# 1. floofer has the highest mean favorite counts
#
# 2. pupper has the lowest mean favorite counts
#
#
# #### Relationship between dog types and rating
#
# A pie chart was plotted to show the average ratings of dogs
# ![Screenshot%20%28158%29.png](attachment:Screenshot%20%28158%29.png)
#
# 1. doggo has the highest average rating
#
# 2. puppo has the lowest average rating
